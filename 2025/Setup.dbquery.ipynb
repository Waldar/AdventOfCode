-- %%
create catalog if not exists identifier(:catalog);
use catalog identifier(:catalog);

create schema if not exists identifier(:schema);
use schema identifier(:schema);

create volume aoc2025;
